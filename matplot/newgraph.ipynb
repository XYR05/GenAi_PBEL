# %%
import matplotlib.pyplot as plt
import numpy as np
x1 = np.array([0,1,2,3,4,5])
y1 = np.array([3,60,67,168,99,210])
colors = np.array(["red","green","blue","yellow","pink","black"])
plt.title(" Sports Watch data")
plt.xlabel("x - axis")
plt.ylabel("y - axis")
plt.scatter(x1, y1, c=colors)
plt.show()
