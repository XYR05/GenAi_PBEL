# %%
import cv2
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ### Detect face

# %%
def detect_face(frame):
    detector=cv2.CascadeClassifier("haarcascade_frontalface_alt.xml")
    face=detector.detectMultiScale(frame,1.2)
    return face

# %% [markdown]
# ### Gray scale

# %%
def gray_scale(image):
    img=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    return img

# %% [markdown]
# ### Cut face

# %%
def cut_face(image,face_coords):
    faces=[]
    for (x,y,w,h) in face_coords:
        img=image[y:y+h,x:x+w]
        faces.append(img)
    return faces

# %% [markdown]
# ### Normalize Intensity

# %%
def normalize_intensity(images):
    normalize_image=[]
    for image in images:
        img=cv2.equalizeHist(image)
        normalize_image.append(img)
    return normalize_image

# %% [markdown]
# ### Resize image

# %%
def resize(images,size=(80,100)):
    resized_images=[]
    for img in images:
        image=cv2.resize(img,size)
        resized_images.append(image)
    return resized_images

# %% [markdown]
# ### Pipeline

# %%
def pipeline(image,face_coords):
    faces=cut_face(image,face_coords)
    faces=normalize_intensity(faces)
    faces=resize(faces)
    return faces

# %% [markdown]
# ### Plot fxn

# %%
def plot_fxn(image,title=''):
    if image.shape==3:
        cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
    plt.axis("off")
    plt.title(title)
    plt.imshow(image,cmap='gray')
    plt.show()

# %% [markdown]
# ### Draw Rectangle

# %%
def draw_rectangle(image,coords):
    for (x,y,w,h) in coords:
        cv2.rectangle(image,(x,y),(x+w,y+h),(0,0,255),2)

# %%
from IPython.display import clear_output

# %% [markdown]
# ### Let's Create DataSet

# %%
cam=cv2.VideoCapture(1)
name=input("Enter folder name: ")
no_sample=int(input("Enter sample no.s: "))
folder="DataSet1/"+name.lower()
if os.path.exists(folder):
    print("Folder with this name is already existed !!!")
else:
    os.mkdir(folder)
    start_cap=False
    sample=1

    cv2.namedWindow(name,cv2.WINDOW_NORMAL)

    while True:
        rect,frame=cam.read()
        gray=gray_scale(frame)
        face_coord=detect_face(gray)

        if len(face_coord)>0:
            faces=pipeline(gray,face_coord)
            img_name=str(sample)+".jpg"
            cv2.imwrite(folder+"/"+img_name,faces[0])
            plot_fxn(faces[0],"Image Saved {}".format(sample))
            clear_output(wait=True)
            if start_cap==True:
                sample+=1 
        else:
            print("No Face found !!!")
        draw_rectangle(frame,face_coord)
        cv2.imshow(name,frame)
        key_press=cv2.waitKey(1)

        if key_press==ord("c"):
            if start_cap==False:
                start_cap=True
        if key_press==ord("q"):
            break
        if sample>no_sample:
            break
    cam.release()
    cv2.destroyAllWindows()

# %% [markdown]
# #### Let's Create Unknown person dataset

# %%
path="D://ADGIPS/archive (10)/lfw-deepfunneled/lfw-deepfunneled"
c=1
for person_name in os.listdir(path)[:200]:
    for image in os.listdir(path+"/"+person_name)[:1]:
        img=cv2.imread(path+"/"+person_name+"/"+image,0)
        face_coord=detect_face(img)
        if len(face_coord)>0:
            imge=pipeline(img,face_coord)
            img_save="DataSet1/unknown/"+str(c)+".jpg"
            cv2.imwrite(img_save,imge[0])
            print(img_save,"Saved !!!")
        c+=1
# Out:
# DataSet1/unknown/1.jpg Saved !!!
# DataSet1/unknown/2.jpg Saved !!!
# DataSet1/unknown/3.jpg Saved !!!
# DataSet1/unknown/4.jpg Saved !!!
# DataSet1/unknown/5.jpg Saved !!!
# DataSet1/unknown/6.jpg Saved !!!
# DataSet1/unknown/7.jpg Saved !!!
# DataSet1/unknown/8.jpg Saved !!!
# DataSet1/unknown/9.jpg Saved !!!
# DataSet1/unknown/10.jpg Saved !!!
# DataSet1/unknown/11.jpg Saved !!!
# DataSet1/unknown/12.jpg Saved !!!
# DataSet1/unknown/13.jpg Saved !!!
# DataSet1/unknown/14.jpg Saved !!!
# DataSet1/unknown/15.jpg Saved !!!
# DataSet1/unknown/16.jpg Saved !!!
# DataSet1/unknown/18.jpg Saved !!!
# DataSet1/unknown/19.jpg Saved !!!
# DataSet1/unknown/20.jpg Saved !!!
# DataSet1/unknown/22.jpg Saved !!!
# DataSet1/unknown/23.jpg Saved !!!
# DataSet1/unknown/24.jpg Saved !!!
# DataSet1/unknown/25.jpg Saved !!!
# DataSet1/unknown/26.jpg Saved !!!
# DataSet1/unknown/27.jpg Saved !!!
# DataSet1/unknown/28.jpg Saved !!!
# DataSet1/unknown/29.jpg Saved !!!
# DataSet1/unknown/30.jpg Saved !!!
# DataSet1/unknown/31.jpg Saved !!!
# DataSet1/unknown/32.jpg Saved !!!
# DataSet1/unknown/33.jpg Saved !!!
# DataSet1/unknown/34.jpg Saved !!!
# DataSet1/unknown/35.jpg Saved !!!
# DataSet1/unknown/36.jpg Saved !!!
# DataSet1/unknown/37.jpg Saved !!!
# DataSet1/unknown/38.jpg Saved !!!
# DataSet1/unknown/39.jpg Saved !!!
# DataSet1/unknown/40.jpg Saved !!!
# DataSet1/unknown/41.jpg Saved !!!
# DataSet1/unknown/42.jpg Saved !!!
# DataSet1/unknown/43.jpg Saved !!!
# DataSet1/unknown/44.jpg Saved !!!
# DataSet1/unknown/45.jpg Saved !!!
# DataSet1/unknown/46.jpg Saved !!!
# DataSet1/unknown/47.jpg Saved !!!
# DataSet1/unknown/49.jpg Saved !!!
# DataSet1/unknown/50.jpg Saved !!!
# DataSet1/unknown/51.jpg Saved !!!
# DataSet1/unknown/52.jpg Saved !!!
# DataSet1/unknown/53.jpg Saved !!!
# DataSet1/unknown/54.jpg Saved !!!
# DataSet1/unknown/55.jpg Saved !!!
# DataSet1/unknown/56.jpg Saved !!!
# DataSet1/unknown/57.jpg Saved !!!
# DataSet1/unknown/58.jpg Saved !!!
# DataSet1/unknown/59.jpg Saved !!!
# DataSet1/unknown/60.jpg Saved !!!
# DataSet1/unknown/61.jpg Saved !!!
# DataSet1/unknown/62.jpg Saved !!!
# DataSet1/unknown/63.jpg Saved !!!
# DataSet1/unknown/64.jpg Saved !!!
# DataSet1/unknown/65.jpg Saved !!!
# DataSet1/unknown/66.jpg Saved !!!
# DataSet1/unknown/67.jpg Saved !!!
# DataSet1/unknown/68.jpg Saved !!!
# DataSet1/unknown/69.jpg Saved !!!
# DataSet1/unknown/70.jpg Saved !!!
# DataSet1/unknown/71.jpg Saved !!!
# DataSet1/unknown/72.jpg Saved !!!
# DataSet1/unknown/73.jpg Saved !!!
# DataSet1/unknown/74.jpg Saved !!!
# DataSet1/unknown/75.jpg Saved !!!
# DataSet1/unknown/76.jpg Saved !!!
# DataSet1/unknown/77.jpg Saved !!!
# DataSet1/unknown/78.jpg Saved !!!
# DataSet1/unknown/79.jpg Saved !!!
# DataSet1/unknown/80.jpg Saved !!!
# DataSet1/unknown/81.jpg Saved !!!
# DataSet1/unknown/82.jpg Saved !!!
# DataSet1/unknown/83.jpg Saved !!!
# DataSet1/unknown/84.jpg Saved !!!
# DataSet1/unknown/85.jpg Saved !!!
# DataSet1/unknown/86.jpg Saved !!!
# DataSet1/unknown/87.jpg Saved !!!
# DataSet1/unknown/88.jpg Saved !!!
# DataSet1/unknown/89.jpg Saved !!!
# DataSet1/unknown/90.jpg Saved !!!
# DataSet1/unknown/91.jpg Saved !!!
# DataSet1/unknown/92.jpg Saved !!!
# DataSet1/unknown/93.jpg Saved !!!
# DataSet1/unknown/94.jpg Saved !!!
# DataSet1/unknown/95.jpg Saved !!!
# DataSet1/unknown/96.jpg Saved !!!
# DataSet1/unknown/97.jpg Saved !!!
# DataSet1/unknown/98.jpg Saved !!!
# DataSet1/unknown/99.jpg Saved !!!
# DataSet1/unknown/100.jpg Saved !!!
# DataSet1/unknown/101.jpg Saved !!!
# DataSet1/unknown/102.jpg Saved !!!
# DataSet1/unknown/103.jpg Saved !!!
# DataSet1/unknown/104.jpg Saved !!!
# DataSet1/unknown/105.jpg Saved !!!
# DataSet1/unknown/106.jpg Saved !!!
# DataSet1/unknown/107.jpg Saved !!!
# DataSet1/unknown/108.jpg Saved !!!
# DataSet1/unknown/109.jpg Saved !!!
# DataSet1/unknown/110.jpg Saved !!!
# DataSet1/unknown/111.jpg Saved !!!
# DataSet1/unknown/112.jpg Saved !!!
# DataSet1/unknown/113.jpg Saved !!!
# DataSet1/unknown/114.jpg Saved !!!
# DataSet1/unknown/115.jpg Saved !!!
# DataSet1/unknown/116.jpg Saved !!!
# DataSet1/unknown/117.jpg Saved !!!
# DataSet1/unknown/118.jpg Saved !!!
# DataSet1/unknown/119.jpg Saved !!!
# DataSet1/unknown/120.jpg Saved !!!
# DataSet1/unknown/121.jpg Saved !!!
# DataSet1/unknown/122.jpg Saved !!!
# DataSet1/unknown/123.jpg Saved !!!
# DataSet1/unknown/124.jpg Saved !!!
# DataSet1/unknown/125.jpg Saved !!!
# DataSet1/unknown/126.jpg Saved !!!
# DataSet1/unknown/127.jpg Saved !!!
# DataSet1/unknown/128.jpg Saved !!!
# DataSet1/unknown/129.jpg Saved !!!
# DataSet1/unknown/130.jpg Saved !!!
# DataSet1/unknown/131.jpg Saved !!!
# DataSet1/unknown/132.jpg Saved !!!
# DataSet1/unknown/133.jpg Saved !!!
# DataSet1/unknown/134.jpg Saved !!!
# DataSet1/unknown/135.jpg Saved !!!
# DataSet1/unknown/136.jpg Saved !!!
# DataSet1/unknown/137.jpg Saved !!!
# DataSet1/unknown/138.jpg Saved !!!
# DataSet1/unknown/139.jpg Saved !!!
# DataSet1/unknown/140.jpg Saved !!!
# DataSet1/unknown/141.jpg Saved !!!
# DataSet1/unknown/142.jpg Saved !!!
# DataSet1/unknown/143.jpg Saved !!!
# DataSet1/unknown/144.jpg Saved !!!
# DataSet1/unknown/145.jpg Saved !!!
# DataSet1/unknown/146.jpg Saved !!!
# DataSet1/unknown/147.jpg Saved !!!
# DataSet1/unknown/148.jpg Saved !!!
# DataSet1/unknown/149.jpg Saved !!!
# DataSet1/unknown/150.jpg Saved !!!
# DataSet1/unknown/151.jpg Saved !!!
# DataSet1/unknown/152.jpg Saved !!!
# DataSet1/unknown/153.jpg Saved !!!
# DataSet1/unknown/154.jpg Saved !!!
# DataSet1/unknown/155.jpg Saved !!!
# DataSet1/unknown/156.jpg Saved !!!
# DataSet1/unknown/157.jpg Saved !!!
# DataSet1/unknown/158.jpg Saved !!!
# DataSet1/unknown/159.jpg Saved !!!
# DataSet1/unknown/160.jpg Saved !!!
# DataSet1/unknown/161.jpg Saved !!!
# DataSet1/unknown/162.jpg Saved !!!
# DataSet1/unknown/163.jpg Saved !!!
# DataSet1/unknown/164.jpg Saved !!!
# DataSet1/unknown/165.jpg Saved !!!
# DataSet1/unknown/166.jpg Saved !!!
# DataSet1/unknown/167.jpg Saved !!!
# DataSet1/unknown/168.jpg Saved !!!
# DataSet1/unknown/169.jpg Saved !!!
# DataSet1/unknown/170.jpg Saved !!!
# DataSet1/unknown/171.jpg Saved !!!
# DataSet1/unknown/172.jpg Saved !!!
# DataSet1/unknown/173.jpg Saved !!!
# DataSet1/unknown/174.jpg Saved !!!
# DataSet1/unknown/175.jpg Saved !!!
# DataSet1/unknown/176.jpg Saved !!!
# DataSet1/unknown/177.jpg Saved !!!
# DataSet1/unknown/178.jpg Saved !!!
# DataSet1/unknown/180.jpg Saved !!!
# DataSet1/unknown/181.jpg Saved !!!
# DataSet1/unknown/182.jpg Saved !!!
# DataSet1/unknown/183.jpg Saved !!!
# DataSet1/unknown/184.jpg Saved !!!
# DataSet1/unknown/185.jpg Saved !!!
# DataSet1/unknown/186.jpg Saved !!!
# DataSet1/unknown/187.jpg Saved !!!
# DataSet1/unknown/188.jpg Saved !!!
# DataSet1/unknown/189.jpg Saved !!!
# DataSet1/unknown/190.jpg Saved !!!
# DataSet1/unknown/192.jpg Saved !!!
# DataSet1/unknown/193.jpg Saved !!!
# DataSet1/unknown/194.jpg Saved !!!
# DataSet1/unknown/195.jpg Saved !!!
# DataSet1/unknown/196.jpg Saved !!!
# DataSet1/unknown/197.jpg Saved !!!
# DataSet1/unknown/198.jpg Saved !!!
# DataSet1/unknown/199.jpg Saved !!!
