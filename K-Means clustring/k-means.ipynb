# %% [markdown]
# # choosing centroid in k means clustring.:
# parameter used to caclcuate the centroid repeteadly is mean?
# Yes, in many clustering algorithms, such as K-means, the centroid of a cluster is calculated as the mean of all the points in that cluster. The algorithm iteratively updates the centroids by calculating the mean of the points assigned to each cluster until convergence is reached.

# %% [markdown]
# # elbow method
# is a technique used to determine the optimal number of clusters in a clustering algorithm, such as K-means. The method involves plotting the explained variation as a function of the number of clusters and looking for an "elbow" point where the rate of decrease sharply slows down. This point indicates the optimal number of clusters to use for the dataset.

# %%
from sklearn.datasets import make_blobs, make_moons

# %%
k_range=range(1, 11)

# %%
kmean=Kmeans
