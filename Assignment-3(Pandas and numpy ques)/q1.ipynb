# %%
import pandas as pd
import numpy as np
#Read csv file
df = pd.read_csv("/home/harry/Internship - ibm/Assignment-3/products.csv")
df.columns = df.columns.str.strip() # Clean column names
df
# Out:
#   Product_Name  Price
# 0       Laptop  50000
# 1        Mouse    800
# 2     Keyboard   1500
# 3      Monitor  12000
# 4      Printer   7000

# %%
avg_price = np.mean(df["Price"])
print("Average price:", avg_price)
# Out:
# Average price: 14260.0

# %%
# function to display products above average price
def above_average_products(data, avg):
    print("\nProducts priced above average:")
    for index, row in data.iterrows():
        if row["Price"] > avg:
            print(row["Product"],"-", row["Price"])
 
# function to display products above average price
def above_average_products(data, avg):
    print("\nProducts priced above average:")
    for index, row in data.iterrows():
        if row["Price"] > avg:
            print(row["Product_Name"], "-", row["Price"])

above_average_products(df, avg_price)
# Out:
# Products priced above average:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Internship - ibm/.venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...
